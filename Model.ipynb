# %% [markdown]
# # Face Mask Detection

# %%
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D,MaxPooling2D,Dropout,Flatten,Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
main_dir = r'C:\Users\MIHIR TAYSHETE\Coursera ML course\kaggle\input\covid-face-mask-detection-dataset\New Masks Dataset'
train_dir = os.path.join(main_dir,'Train')
test_dir = os.path.join(main_dir,'Test')
validation_dir = os.path.join(main_dir,'Validation')

train_mask_dir = os.path.join(train_dir,'Mask')
train_non_mask_dir = os.path.join(train_dir,'Non Mask')

# %%
train_mask_dir_names = os.listdir(train_mask_dir)
train_non_mask_dir_names = os.listdir(train_non_mask_dir)

print(train_mask_dir_names[:10])
print(train_non_mask_dir_names[:10])
# Out:
# ['0003.jpg', '0006.jpg', '0018.jpg', '0019.jpg', '0022.jpg', '0027.jpg', '0029.jpg', '0037.jpg', '0040.jpg', '0042.jpg']
# ['0.jpg', '1.jpg', '10.jpg', '100.jpg', '101.jpg', '102.jpg', '104.jpg', '105.jpg', '106.jpg', '107.jpg']

# %%
import matplotlib.image as npimg
nrows=4
ncols=4
plt.figure(figsize=(12,12))

mask_pic = []

for i in train_mask_dir_names[0:8]:
  mask_pic.append(os.path.join(train_mask_dir,i))

no_mask_pic = []

for i in train_non_mask_dir_names[0:8]:
  no_mask_pic.append(os.path.join(train_non_mask_dir,i))

# %%
merged_list = mask_pic + no_mask_pic

for i in range(0,len(merged_list)):
  data = merged_list[i].split('/',0)[0]
  sp = plt.subplot(nrows,ncols,i+1)
  plt.axis('Off')
  image = npimg.imread(merged_list[i])
  plt.imshow(image,cmap='gray')
plt.show()

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   zoom_range=0.2,
                                   rotation_range=40,
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_images_generator = train_datagen.flow_from_directory(train_dir,
                                                           target_size=(180,180),
                                                           batch_size=32,
                                                           class_mode='binary')

test_images_generator = test_datagen.flow_from_directory(test_dir,
                                                           target_size=(180,180),
                                                           batch_size=32,
                                                           class_mode='binary')

valid_images_generator = validation_datagen.flow_from_directory(validation_dir,
                                                           target_size=(180,180),
                                                           batch_size=32,
                                                           class_mode='binary')
# Out:
# Found 600 images belonging to 2 classes.
# Found 100 images belonging to 2 classes.
# Found 306 images belonging to 2 classes.

# %%
train_images_generator.class_indices
# Out:
# {'Mask': 0, 'Non Mask': 1}

# %%
train_images_generator.image_shape
# Out:
# (180, 180, 3)

# %% [markdown]
# ***Building Convolutional neural network***

# %%
model = Sequential()
model.add(Conv2D(32,(3,3),padding='SAME',activation='relu',input_shape=(180,180,3)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(64,(3,3),padding='SAME',activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Flatten())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 180, 180, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 90, 90, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 90, 90, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 90, 90, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 45, 45, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 45, 45, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 129600)            0
# _________________________________________________________________
# dense (Dense)                (None, 64)                8294464
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 8,313,921
# Trainable params: 8,313,921
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(Adam(learning_rate=0.001),loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(train_images_generator,epochs=100,validation_data=valid_images_generator)
# Out:
# Epoch 1/100
# 19/19 [==============================] - 27s 1s/step - loss: 1.1515 - accuracy: 0.6200 - val_loss: 0.5389 - val_accuracy: 0.8203
# Epoch 2/100
# 19/19 [==============================] - 19s 1s/step - loss: 0.3800 - accuracy: 0.8533 - val_loss: 0.4037 - val_accuracy: 0.8562
# Epoch 3/100
# 19/19 [==============================] - 18s 974ms/step - loss: 0.3211 - accuracy: 0.8917 - val_loss: 0.2827 - val_accuracy: 0.8987
# Epoch 4/100
# 19/19 [==============================] - 17s 887ms/step - loss: 0.3011 - accuracy: 0.8867 - val_loss: 0.2814 - val_accuracy: 0.8922
# Epoch 5/100
# 19/19 [==============================] - 23s 1s/step - loss: 0.2552 - accuracy: 0.9067 - val_loss: 0.2003 - val_accuracy: 0.9281
# Epoch 6/100
# 19/19 [==============================] - 21s 1s/step - loss: 0.2371 - accuracy: 0.9067 - val_loss: 0.2238 - val_accuracy: 0.9216
# Epoch 7/100
# 19/19 [==============================] - 24s 1s/step - loss: 0.2407 - accuracy: 0.9100 - val_loss: 0.2566 - val_accuracy: 0.9020
# Epoch 8/100
# 19/19 [==============================] - 23s 1s/step - loss: 0.2395 - accuracy: 0.9150 - val_loss: 0.2198 - val_accuracy: 0.9150
# Epoch 9/100
# 19/19 [==============================] - 21s 1s/step - loss: 0.2312 - accuracy: 0.9133 - val_loss: 0.2504 - val_accuracy: 0.9085
# Epoch 10/100
# 19/19 [==============================] - 21s 1s/step - loss: 0.2058 - accuracy: 0.9233 - val_loss: 0.2326 - val_accuracy: 0.8987
# Epoch 11/100
# 19/19 [==============================] - 21s 1s/step - loss: 0.2151 - accuracy: 0.9317 - val_loss: 0.2583 - val_accuracy: 0.9052
# Epoch 12/100
# 19/19 [==============================] - 21s 1s/step - loss: 0.2054 - accuracy: 0.9350 - val_loss: 0.2401 - val_accuracy: 0.8922
# Epoch 13/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.1801 - accuracy: 0.9333 - val_loss: 0.2375 - val_accuracy: 0.9118
# Epoch 14/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.2096 - accuracy: 0.9267 - val_loss: 0.2293 - val_accuracy: 0.9150
# Epoch 15/100
# 19/19 [==============================] - 21s 1s/step - loss: 0.1733 - accuracy: 0.9367 - val_loss: 0.2368 - val_accuracy: 0.8954
# Epoch 16/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.1954 - accuracy: 0.9400 - val_loss: 0.2509 - val_accuracy: 0.8791
# Epoch 17/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.1915 - accuracy: 0.9233 - val_loss: 0.1988 - val_accuracy: 0.9248
# Epoch 18/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.2085 - accuracy: 0.9283 - val_loss: 0.2169 - val_accuracy: 0.9118
# Epoch 19/100
# 19/19 [==============================] - 21s 1s/step - loss: 0.1916 - accuracy: 0.9367 - val_loss: 0.2051 - val_accuracy: 0.9150
# Epoch 20/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.1740 - accuracy: 0.9483 - val_loss: 0.2476 - val_accuracy: 0.9150
# Epoch 21/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.1724 - accuracy: 0.9433 - val_loss: 0.3272 - val_accuracy: 0.9052
# Epoch 22/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.2008 - accuracy: 0.9133 - val_loss: 0.2427 - val_accuracy: 0.9118
# Epoch 23/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.2066 - accuracy: 0.9217 - val_loss: 0.2291 - val_accuracy: 0.9118
# Epoch 24/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.1655 - accuracy: 0.9417 - val_loss: 0.2433 - val_accuracy: 0.9052
# Epoch 25/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.1531 - accuracy: 0.9517 - val_loss: 0.2590 - val_accuracy: 0.8987
# Epoch 26/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.1614 - accuracy: 0.9317 - val_loss: 0.2181 - val_accuracy: 0.9020
# Epoch 27/100
# 19/19 [==============================] - 22s 1s/step - loss: 0.1772 - accuracy: 0.9367 - val_loss: 0.2253 - val_accuracy: 0.9216
# Epoch 28/100
# 19/19 [==============================] - 22s 1s/step - loss: 0
# 19/19 [==============================] - 17s 900ms/step - loss: 0.1465 - accuracy: 0.9267 - val_loss: 0.2744 - val_accuracy: 0.9085
# Epoch 70/100
# 19/19 [==============================] - 17s 899ms/step - loss: 0.1083 - accuracy: 0.9583 - val_loss: 0.3283 - val_accuracy: 0.9052
# Epoch 71/100
# 19/19 [==============================] - 17s 897ms/step - loss: 0.1422 - accuracy: 0.9467 - val_loss: 0.2819 - val_accuracy: 0.9085
# Epoch 72/100
# 19/19 [==============================] - 17s 904ms/step - loss: 0.1209 - accuracy: 0.9483 - val_loss: 0.2851 - val_accuracy: 0.9150
# Epoch 73/100
# 19/19 [==============================] - 17s 900ms/step - loss: 0.1085 - accuracy: 0.9550 - val_loss: 0.3548 - val_accuracy: 0.8987
# Epoch 74/100
# 19/19 [==============================] - 18s 950ms/step - loss: 0.1290 - accuracy: 0.9450 - val_loss: 0.2867 - val_accuracy: 0.9248
# Epoch 75/100
# 19/19 [==============================] - 18s 955ms/step - loss: 0.0975 - accuracy: 0.9650 - val_loss: 0.3732 - val_accuracy: 0.8922
# Epoch 76/100
# 19/19 [==============================] - 18s 972ms/step - loss: 0.1326 - accuracy: 0.9583 - val_loss: 0.3343 - val_accuracy: 0.8693
# Epoch 77/100
# 19/19 [==============================] - 18s 957ms/step - loss: 0.1151 - accuracy: 0.9433 - val_loss: 0.2891 - val_accuracy: 0.9052
# Epoch 78/100
# 19/19 [==============================] - 18s 976ms/step - loss: 0.1227 - accuracy: 0.9567 - val_loss: 0.3088 - val_accuracy: 0.9118
# Epoch 79/100
# 19/19 [==============================] - 18s 984ms/step - loss: 0.0923 - accuracy: 0.9650 - val_loss: 0.3237 - val_accuracy: 0.9020
# Epoch 80/100
# 19/19 [==============================] - 18s 950ms/step - loss: 0.1111 - accuracy: 0.9567 - val_loss: 0.3175 - val_accuracy: 0.9020
# Epoch 81/100
# 19/19 [==============================] - 18s 936ms/step - loss: 0.1263 - accuracy: 0.9583 - val_loss: 0.2657 - val_accuracy: 0.9085
# Epoch 82/100
# 19/19 [==============================] - 18s 954ms/step - loss: 0.0886 - accuracy: 0.9650 - val_loss: 0.2974 - val_accuracy: 0.9281
# Epoch 83/100
# 19/19 [==============================] - 18s 951ms/step - loss: 0.1269 - accuracy: 0.9500 - val_loss: 0.2802 - val_accuracy: 0.9020
# Epoch 84/100
# 19/19 [==============================] - 19s 1s/step - loss: 0.1117 - accuracy: 0.9467 - val_loss: 0.3102 - val_accuracy: 0.9052
# Epoch 85/100
# 19/19 [==============================] - 18s 952ms/step - loss: 0.0928 - accuracy: 0.9700 - val_loss: 0.3680 - val_accuracy: 0.9118
# Epoch 86/100
# 19/19 [==============================] - 18s 949ms/step - loss: 0.1268 - accuracy: 0.9550 - val_loss: 0.3051 - val_accuracy: 0.9150
# Epoch 87/100
# 19/19 [==============================] - 18s 944ms/step - loss: 0.1157 - accuracy: 0.9617 - val_loss: 0.3465 - val_accuracy: 0.9085
# Epoch 88/100
# 19/19 [==============================] - 18s 952ms/step - loss: 0.1078 - accuracy: 0.9633 - val_loss: 0.2889 - val_accuracy: 0.9085
# Epoch 89/100
# 19/19 [==============================] - 18s 946ms/step - loss: 0.1030 - accuracy: 0.9533 - val_loss: 0.3065 - val_accuracy: 0.9118
# Epoch 90/100
# 19/19 [==============================] - 19s 1s/step - loss: 0.0952 - accuracy: 0.9617 - val_loss: 0.2882 - val_accuracy: 0.9118
# Epoch 91/100
# 19/19 [==============================] - 18s 971ms/step - loss: 0.0981 - accuracy: 0.9500 - val_loss: 0.3807 - val_accuracy: 0.9150
# Epoch 92/100
# 19/19 [==============================] - 18s 958ms/step - loss: 0.1279 - accuracy: 0.9483 - val_loss: 0.3090 - val_accuracy: 0.9150
# Epoch 93/100
# 19/19 [==============================] - 19s 1s/step - loss: 0.1344 - accuracy: 0.9567 - val_loss: 0.2670 - val_accuracy: 0.9183
# Epoch 94/100
# 19/19 [==============================] - 19s 1s/step - loss: 0.1298 - accuracy: 0.9533 - val_loss: 0.2811 - val_accuracy: 0.9118
# Epoch 95/100
# 19/19 [==============================] - 18s 946ms/step - loss: 0.1087 - accuracy: 0.9500 - val_loss: 0.2834 - val_accuracy: 0.9085
# Epoch 96/100
# 19/19 [==============================] - 18s 938ms/step - loss: 0.1131 - accuracy: 0.9550 - val_loss: 0.2916 - val_accuracy: 0.9216
# Epoch 97/100
# 19/19 [==============================] - 18s 944ms/step - loss: 0.1188 - accuracy: 0.9583 - val_loss: 0.2498 - val_accuracy: 0.9118
# Epoch 98/100
# 19/19 [==============================] - 18s 942ms/step - loss: 0.1393 - accuracy: 0.9350 - val_loss: 0.2760 - val_accuracy: 0.9183
# Epoch 99/100
# 19/19 [==============================] - 18s 937ms/step - loss: 0.1198 - accuracy: 0.9567 - val_loss: 0.2549 - val_accuracy: 0.9281
# Epoch 100/100
# 19/19 [==============================] - 18s 936ms/step - loss: 0.1016 - accuracy: 0.9567 - val_loss: 0.2892 - val_accuracy: 0.9150

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['Training','Validation'])
plt.title("Training And Validation Loss")
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
test_loss , test_acc = model.evaluate(test_images_generator)

print("Test Loss: {} Test Accuracy: {}".format(test_loss,test_acc))
# Out:
# 4/4 [==============================] - 2s 419ms/step - loss: 0.1232 - accuracy: 0.9600
# Test Loss: 0.12320563942193985 Test Accuracy: 0.9599999785423279

# %% [markdown]
# ***As We See Our Model Is Not Overfitted.***

# %%
model.save('face_mask_detection.h5')

# %%
import matplotlib.image as mpimg
from keras.preprocessing import image

def test_image_mask_nomask(path):
    im = mpimg.imread(path)
    plt.imshow(im)
    
    img = image.load_img(path,target_size=(180,180))
    img = image.img_to_array(img)
    img = np.expand_dims(img,axis=0)
    prediction = model.predict(img)
    if prediction == 0:
        
        print("Person Wearing A Mask")

    else:
        print("Person Not Wearing A Mask")

# %%
test_image_mask_nomask(r'C:\Users\MIHIR TAYSHETE\Coursera ML course\kaggle\input\covid-face-mask-detection-dataset\New Masks Dataset\Test\Mask/2265.png')
# Out:
# Person Wearing A Mask

# %%
test_image_mask_nomask(r'C:\Users\MIHIR TAYSHETE\Coursera ML course\kaggle\input\covid-face-mask-detection-dataset\New Masks Dataset\Test\Non Mask/real_01050.jpg')
# Out:
# Person Not Wearing A Mask
